# %%
import pandas as pd

# %%
#Load the csv file
dataset = pd.read_csv("kidney_disease.csv")

# %%
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
#Preview the first few rows
print(dataset.head())
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
#check shape (rows, columns)
print("shape:",dataset.shape)
# Out:
# shape: (400, 26)

# %%
dataset.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
def quanQual(dataset):
        nominal_cols = []
        ordinal_cols = []
        for columnName in dataset.columns:
            if(dataset[columnName].dtype == 'O'):
                nominal_cols.append(columnName)
            else:
                ordinal_cols.append(columnName)
        return nominal_cols, ordinal_cols

# %%
nominal_cols, ordinal_cols = quanQual(dataset)

# %%
#Summary of numeric features
print(dataset.describe())
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
#First Step
#Check how many missing values each column has
print(dataset.isnull().sum())
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
# Impute ordinal columns with median using SimpleImputer
from sklearn.impute import SimpleImputer

ordinal_imputer = SimpleImputer(strategy='median')
dataset[ordinal_cols] = ordinal_imputer.fit_transform(dataset[ordinal_cols])

# %%
dataset[ordinal_cols]
# Out:
#         id   age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2  138.0  4.4  15.4
# 1      1.0   7.0  50.0  1.020  4.0  0.0  121.0  18.0  0.8  138.0  4.4  11.3
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8  138.0  4.4   9.6
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4  138.0  4.4  11.6
# ..     ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8
#
# [400 rows x 12 columns]

# %%
#for nominal (categorical) columns: use mode (most frequent)
for columnName in nominal_cols:
    dataset[columnName] = dataset[columnName].fillna(dataset[columnName].mode()[0])

# %%
dataset[nominal_cols]
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0    normal    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1    normal    normal  notpresent  notpresent  38  6000  5.2   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  5.2   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
print(dataset.head())
# Out:
#     id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  0.0  48.0  80.0  1.020  1.0  0.0  normal    normal  notpresent  notpresent
# 1  1.0   7.0  50.0  1.020  4.0  0.0  normal    normal  notpresent  notpresent
# 2  2.0  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  3.0  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  4.0  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  5.2   no   no   no  good   no   no            ckd
# 2  ...   31  7500  5.2   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
dataset.isnull().sum()
# Out:
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
#Second Step
#Check for outliers
dataset.describe()
# Out:
#                id         age          bp          sg         al          su  \
# count  400.000000  400.000000  400.000000  400.000000  400.00000  400.000000
# mean   199.500000   51.562500   76.575000    1.017712    0.90000    0.395000
# std    115.614301   16.982996   13.489785    0.005434    1.31313    1.040038
# min      0.000000    2.000000   50.000000    1.005000    0.00000    0.000000
# 25%     99.750000   42.000000   70.000000    1.015000    0.00000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.00000    0.000000
# 75%    299.250000   64.000000   80.000000    1.020000    2.00000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.00000    5.000000
#
#               bgr          bu          sc         sod         pot       hemo
# count  400.000000  400.000000  400.000000  400.000000  400.000000  400.00000
# mean   145.062500   56.693000    2.997125  137.631250    4.577250   12.54250
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def Univariate(dataset, ordinal_cols):
        descriptive = pd.DataFrame(index = ["Mean", "Median", "Mode", "Q1:25%", "Q2:50%",
                                            "Q3:75%", "Q4:100%", "IQR", "1.5rule", "Lesser", "Greater", "Min", "Max"], columns = ordinal_cols)
        for columnName in ordinal_cols:
            descriptive[columnName]["Mean"] = dataset[columnName].mean()
            descriptive[columnName]["Median"] = dataset[columnName].median()
            descriptive[columnName]["Mode"] = dataset[columnName].mode()[0]
            descriptive[columnName]["Q1:25%"] = dataset.describe()[columnName]["25%"]
            descriptive[columnName]["Q2:50%"] = dataset.describe()[columnName]["50%"]
            descriptive[columnName]["Q3:75%"] = dataset.describe()[columnName]["75%"]
            descriptive[columnName]["Q4:100%"] = dataset.describe()[columnName]["max"]
            descriptive[columnName]["IQR"] = descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
            descriptive[columnName]["1.5rule"] = 1.5 * descriptive[columnName]["IQR"]
            descriptive[columnName]["Lesser"] = descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
            descriptive[columnName]["Greater"] = descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
            descriptive[columnName]["Min"] = dataset[columnName].min()
            descriptive[columnName]["Max"] = dataset[columnName].max()
        return descriptive

# %%
descriptive = Univariate(dataset, ordinal_cols)

# %%
descriptive
# Out:
#              id      age      bp        sg   al     su       bgr       bu  \
# Mean      199.5  51.5625  76.575  1.017712  0.9  0.395  145.0625   56.693
# Median    199.5     55.0    80.0      1.02  0.0    0.0     121.0     42.0
# Mode        0.0     55.0    80.0      1.02  0.0    0.0     121.0     42.0
# Q1:25%    99.75     42.0    70.0     1.015  0.0    0.0     101.0     27.0
# Q2:50%    199.5     55.0    80.0      1.02  0.0    0.0     121.0     42.0
# Q3:75%   299.25     64.0    80.0      1.02  2.0    0.0     150.0    61.75
# Q4:100%   399.0     90.0   180.0     1.025  5.0    5.0     490.0    391.0
# IQR       199.5     22.0    10.0     0.005  2.0    0.0      49.0    34.75
# 1.5rule  299.25     33.0    15.0    0.0075  3.0    0.0      73.5   52.125
# Lesser   -199.5      9.0    55.0    1.0075 -3.0    0.0      27.5  -25.125
# Greater   598.5     97.0    95.0    1.0275  5.0    0.0     223.5  113.875
# Min         0.0      2.0    50.0     1.005  0.0    0.0      22.0      1.5
# ...

# %%
lesser = []
greater = []

for columnName in ordinal_cols:
    if(descriptive[columnName]["Min"] < descriptive[columnName]["Lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["Max"] > descriptive[columnName]["Greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# ['age', 'bp', 'sg', 'bgr', 'sod', 'pot', 'hemo']

# %%
greater
# Out:
# ['bp', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot']

# %%
for columnName in lesser:
    dataset[columnName][dataset[columnName] < descriptive[columnName]["Lesser"]] = descriptive[columnName]["Lesser"]
for columnName in greater:
    dataset[columnName][dataset[columnName] > descriptive[columnName]["Greater"]] = descriptive[columnName]["Greater"]

# %%
descriptive = Univariate(dataset, ordinal_cols)

# %%
descriptive
# Out:
#              id      age      bp        sg   al   su        bgr         bu  \
# Mean      199.5  51.6475  75.825  1.017756  0.9  0.0  134.01125  50.277687
# Median    199.5     55.0    80.0      1.02  0.0  0.0      121.0       42.0
# Mode        0.0     55.0    80.0      1.02  0.0  0.0      223.5    113.875
# Q1:25%    99.75     42.0    70.0     1.015  0.0  0.0      101.0       27.0
# Q2:50%    199.5     55.0    80.0      1.02  0.0  0.0      121.0       42.0
# Q3:75%   299.25     64.0    80.0      1.02  2.0  0.0      150.0      61.75
# Q4:100%   399.0     90.0    95.0     1.025  5.0  0.0      223.5    113.875
# IQR       199.5     22.0    10.0     0.005  2.0  0.0       49.0      34.75
# 1.5rule  299.25     33.0    15.0    0.0075  3.0  0.0       73.5     52.125
# Lesser   -199.5      9.0    55.0    1.0075 -3.0  0.0       27.5    -25.125
# Greater   598.5     97.0    95.0    1.0275  5.0  0.0      223.5    113.875
# ...

# %%
lesser = []
greater = []

for columnName in ordinal_cols:
    if(descriptive[columnName]["Min"] < descriptive[columnName]["Lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["Max"] > descriptive[columnName]["Greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
dataset
# Out:
#         id   age    bp      sg   al   su     rbc        pc         pcc  \
# 0      0.0  48.0  80.0  1.0200  1.0  0.0  normal    normal  notpresent
# 1      1.0   9.0  55.0  1.0200  4.0  0.0  normal    normal  notpresent
# 2      2.0  62.0  80.0  1.0100  2.0  0.0  normal    normal  notpresent
# 3      3.0  48.0  70.0  1.0075  4.0  0.0  normal  abnormal     present
# 4      4.0  51.0  80.0  1.0100  2.0  0.0  normal    normal  notpresent
# ..     ...   ...   ...     ...  ...  ...     ...       ...         ...
# 395  395.0  55.0  80.0  1.0200  0.0  0.0  normal    normal  notpresent
# 396  396.0  42.0  70.0  1.0250  0.0  0.0  normal    normal  notpresent
# 397  397.0  12.0  80.0  1.0200  0.0  0.0  normal    normal  notpresent
# 398  398.0  17.0  60.0  1.0250  0.0  0.0  normal    normal  notpresent
# 399  399.0  58.0  80.0  1.0250  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# ...
